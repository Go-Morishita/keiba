# %%
import scraping
import pickle # pythonのデータ保存ライブラリ
import create_rawdf
# %load_ext autoreload

# %%
# %autoreload

# %%
from pathlib import Path # windowsとmacによる環境の違いを防ぐためにpathlibを使用

HTML_DIR = Path("..", "data", "html")
HTML_RACE_DIR = HTML_DIR / "race"

# %% [markdown]
# # データ取得

# %% [markdown]
# ## 開催日一覧を取得

# %%
kaisai_date_list = scraping.scrape_kaisai_date(from_="2023-01", to_="2023-12")
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]

# %% [markdown]
# ## レースidを取得

# %%
race_id_list = scraping.scrape_race_id_list(kaisai_date_list)
# Out:
#   0%|          | 0/107 [00:00<?, ?it/s]

# %%
with open("race_id_list.pickle", "wb") as f:
    pickle.dump(race_id_list, f)

# %% [markdown]
# ## raceページの取得

# %%
with open("race_id_list.pickle", "rb") as f:
    race_id_list = pickle.load(f)

# %%
html_paths_race = scraping.scrape_html_race(race_id_list=race_id_list)
# Out:
#   0%|          | 0/3456 [00:00<?, ?it/s]
# skipped: 202306010101
# skipped: 202306010102
# skipped: 202306010103
# skipped: 202306010104
# skipped: 202306010105
# skipped: 202306010106
# skipped: 202306010107
# skipped: 202306010108
# skipped: 202306010109
# skipped: 202306010110
# skipped: 202306010111
# skipped: 202306010112
# skipped: 202307010101
# skipped: 202307010102
# skipped: 202307010103
# skipped: 202307010104
# skipped: 202307010105
# skipped: 202307010106
# skipped: 202307010107
# skipped: 202307010108
# skipped: 202307010109
# skipped: 202307010110
# skipped: 202307010111
# skipped: 202307010112
# skipped: 202306010201
# skipped: 202306010202
# skipped: 202306010203
# skipped: 202306010204
# skipped: 202306010205
# skipped: 202306010206
# skipped: 202306010207
# skipped: 202306010208
# skipped: 202306010209
# skipped: 202306010210
# skipped: 202306010211
# skipped: 202306010212
# skipped: 202307010201
# skipped: 202307010202
# skipped: 202307010203
# ...

# %%
html_paths_race = list(HTML_RACE_DIR.glob("*")) # glob"*"で全てのPathを取得.

# %%
results = create_rawdf.create_resuls(html_path_list=html_paths_race)
# Out:
#   0%|          | 0/3456 [00:00<?, ?it/s]

# %%
results
# Out:
#              着 順  枠 番  馬 番         馬名  性齢    斤量    騎手     タイム     着差     単勝  \
# race_id
# 202301010101   1    5    5    サトミノキラリ  牡2  55.0  横山武史  1:09.5    NaN    1.2
# 202301010101   2    8    8     ベアゴーゴー  牝2  55.0   浜中俊  1:09.5     クビ    4.1
# 202301010101   3    6    6  ハピアーザンエバー  牡2  55.0  藤岡佑介  1:10.0  2.1/2   59.9
# 202301010101   4    4    4  デビルシズカチャン  牝2  55.0  ルメール  1:10.2  1.1/2   16.6
# 202301010101   5    1    1   ウィスピースノー  牝2  55.0  吉田隼人  1:10.3    1/2   23.9
# ...           ..  ...  ...        ...  ..   ...   ...     ...    ...    ...
# 202310030812   8    1    1      リヴァーレ  牝3  53.0  太宰啓介  2:42.9  1.1/4   62.8
# 202310030812   9    6    7   シュアーウィナー  牡5  55.0  川端海翼  2:43.5  3.1/2  125.6
# 202310030812  10    2    2   アウローラシエル  牡3  55.0  和田竜二  2:43.6    3/4    9.8
# 202310030812  11    4    4   ハイグッドエース  牡4  55.0  西塚洸二  2:43.7    3/4   37.2
# 202310030812  12    5    5    コスモフランメ  牝3  52.0  角田大河  2:44.1  2.1/2    6.2
#
#                人 気       馬体重       調教師
# ...
